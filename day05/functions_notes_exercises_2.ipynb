# %%
# Example 1 - Function without Parameters
def generate_full_name():
    first_name = "Kite"
    last_name = "Ranger"
    space = " "
    full_name = first_name + space + last_name
    print(full_name)

generate_full_name()
# Out:
# Kite Ranger

# %%
# Example 1.1 - Function without Parameters
def add_two_numbers():
    num_one = 3
    num_two = 4
    total = num_one + num_two
    print(total)

add_two_numbers()
# Out:
# 7

# %%
# Example 1.2 - Function without Parameters and with Return value
def generate_full_name():
    first_name = "Kite"
    last_name = "Ranger"
    space = " "
    full_name = first_name + space + last_name
    return full_name

print(generate_full_name())
# Out:
# Kite Ranger

# %%
# Example 1.3 - Function without Parameters and with Return value
def add_two_numbers():
    num_one = 3
    num_two = 4
    total = num_one + num_two
    return total

print(add_two_numbers())
# Out:
# 7

# %%
# Example 2 - Function with Parameters - One parameter
def greetings(name):
    message = name + ', Welcome to the Jungle '
    return message

print(greetings("You Can't See Me"))
# Out:
# You Can't See Me, Welcome to the Jungle

# %%
# Example 2.1 - Function with Parameters - One parameter
def add_ten(num):
    ten = 10
    return num + ten

print(add_ten(90))
# Out:
# 100

# %%
# Example 2.2 - Function with Parameters - One parameter - Squaring numbers
def square_number(x):
    return x * x

print(square_number(5))
# Out:
# 25

# %%
# Example 2.3 - Function with Parameters - One parameter - Area of circle
def area_of_circle(r):
    pi = 3.14
    area = pi * r ** 2
    return area

print(area_of_circle(10))
# Out:
# 314.0

# %%
# Example 2.4 - Function with Parameters - One parameter - Sum of numbers
def sum_of_numbers(n):
    total = 0
    for i in range(n + 1):
        total += i
    return total

print(sum_of_numbers(10))
print(sum_of_numbers(100))
# Out:
# 55
# 5050

# %%
# Example 3 - Function with Parameters - Two parameters
def generate_full_name(first_name, last_name):
    space = ' '
    full_name = first_name + space + last_name
    return full_name

print('Full Name: ', generate_full_name('Flying','Eagle'))

# Example 3.1 - Sum of 2 numbers
def sum_two_numbers(num_one, num_two):
    sum = num_one + num_two
    return sum

print('Sum of two numbers: ', sum_two_numbers(1, 9))

# Example 3.2 - Calculate Age
def calculate_age(current_year, birth_year):
    age = current_year - birth_year
    return age

print('Age: ', calculate_age(2021, 1819))

# Example 3.4 - Weight of Object in Newton's scale
def weight_of_object(mass, gravity):
    weight = str(mass * gravity)+ ' N'
    return weight
print('Weight of an object in Newtons: ', weight_of_object(100, 9.81))
# Out:
# Full Name:  Flying Eagle
# Sum of two numbers:  10
# Age:  202
# Weight of an object in Newtons:  981.0 N

# %%
# Example 4 - Passing Arguments with Key and Value
def print_fullname(first_name, last_name):
    space = ' '
    full_name = first_name + space + last_name
    return full_name

print(print_fullname(first_name='Dracarys', last_name='Queen'))

# Example 4.1 - Passing Arguments with Key and Value # Order does not matter
def add_two_numbers(num1, num2):
    total = num1 + num2
    return total

print(add_two_numbers(num2=3, num1=2))
# Out:
# Dracarys Queen
# 5

# %%
# Example 5
def is_even(n):
    if n % 2 == 0:           # return stops further execution of the function, similar to break
        return True
    return False

print(is_even(10))
print(is_even(7))
# Out:
# True
# False

# %%
# Example 6
def find_even_numbers(n):
    evens = []
    for i in range(n + 1):
        if i % 2 == 0:
            evens.append(i)
    return evens

print(find_even_numbers(10))
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
# Function with Default Parameters
# Sometimes we pass default values to parameters, when we invoke the function. If we do not pass arguments when calling the function, their default values will be used.
# Example 7.1
def greetings(name = 'Peter'):
    message = name + ', Welcome to the jungle!'
    return message

print(greetings())
print(greetings("Legendary"))

# Example 7.2
def generate_full_name(first_name = "Peter", last_name = "Fernadiz"):
    space = ' '
    full_name = first_name + space + last_name
    return full_name

print(generate_full_name())
print(generate_full_name("David", "Smith"))

# Example 7.3
def weight_of_object (mass, gravity = 9.81):
    weight = str(mass * gravity)+ ' N' # the value has to be changed to string first
    return weight

print('Weight of an object in Newtons: ', weight_of_object(100)) # 9.81 - average gravity on Earth's surface
print('Weight of an object in Newtons: ', weight_of_object(100, 1.62)) # gravity on the surface of the Moon
# Out:
# Peter, Welcome to the jungle!
# Legendary, Welcome to the jungle!
# Peter Fernadiz
# David Smith
# Weight of an object in Newtons:  981.0 N
# Weight of an object in Newtons:  162.0 N

# %% [markdown]
# ##### Arbitrary Number of Arguments
# If we do not know the number of arguments we pass to our function, we can create a function which can take arbitrary number of arguments by adding * before the parameter name.
#
# ``# syntax
#    Declaring a function
# def function_name(*args):
#     codes
#     codes
# Calling function
# function_name(param1, param2, param3,..)``

# %%
# Example 8
def sum_all_nums(*nums):
    total = 0
    for num in nums:
        total += num
    return total

print(sum_all_nums(2, 3, 5))
# Out:
# 10

# %%
# Example 8.1 - Default and Arbitrary Number of Parameters in Functions
def generate_groups (team='X force',*args):
    print(team)
    for i in args:
        print(i)
generate_groups('Team-1','Deadpool','Vanisher','David','Wolverine')
# Out:
# Team-1
# Deadpool
# Vanisher
# David
# Wolverine

# %%
# Dictionary unpacking - You can call a function which has named arguments using a dictionary with matching key names. You do so using **.
# Example 9.1
# Define a function that takes two arguments: 'name' and 'location'
def greet(name, location):
    # Print a greeting message using the provided arguments
    print("Hi there", name, "how is the weather in", location)

# Call the function using keyword arguments
greet(name="Alice", location="New York")
# Output: Hi there Alice how is the weather in New York

# Create a dictionary with keys matching the function's parameter names
my_dict = {"name": "Alice", "location": "New York"}

# Call the function using dictionary unpacking
greet(**my_dict)
# The ** operator unpacks the dictionary, passing its key-value pairs
# as keyword arguments to the function.
# Output: Hi there Alice how is the weather in New York
# Out:
# Hi there Alice how is the weather in New York
# Hi there Alice how is the weather in New York

# %%
# Arbitrary Number of Named Arguments.You can also define a function to accept an arbitrary number of named arguments.
def arbitrary_named_args(**args):
    print("I received an arbitrary number of arguments, totaling", len(args))
    print("They are provided as a dictionary in my function:", type(args))
    print("Let's print them:")
    for k, v in args.items():
        print(" * key:", k, "value:", v)

# Generally avoid this unless required as it makes it harder to understand what the function accepts and does.

# %%
# Function as a Parameter of Another Function
#You can pass functions around as parameters
def square_number (n):
    return n ** n
def do_something(f, x):
    return f(x)
print(do_something(square_number, 3))
# Out:
# 27
